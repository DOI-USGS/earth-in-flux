# %% [markdown]
# # {Project name} chart for Climate Chart Gallery
# {Title}<br>{Your name}<br>{The date}

# %% [markdown]
# ## Instructions for using this template
#
# > Make sure you have copied the template subdirectory and named it with your project name and your name (e.g., `/FishAsFood_hcorson-dosch`) before editing this document!
#
# 1. Put all comments either in markdown text (like this) or in the `Python` cells to explain your process to Vizlab reviewers
# 2. Put all Python code in the Python cells within each section. The sections are organized for you to (in order): do some set-up steps (import packages), load in any data (manually or with built in packages), process your data for plotting, create a plot using matplotlib, and finally compose the final image in a mobile or square (Instagram) layout.
# 3. You can run individual code chunks while developing code and plots.
# 4. Make sure to save your output `png` in the `out/` folder, ideally named with the name of your project and your name.
# 5. When you're happy with the final plot, fill out the supporting information at the bottom and push to GitLab for review. Note: only commit input data if it can't be downloaded directly with code.

# %% [markdown]
# ## Set up
# Import packages here

# %%
# Import required packages for data loading/analysis



# Import required packages for plotting and plot composition
import matplotlib.pyplot as plt
import matplotlib.image as image
from matplotlib.offsetbox import (OffsetImage, AnnotationBbox)

# %% [markdown]
# ## Load files
#
# Save any files that you are using directly in the `in` folder. Then read them in to the environment with this chunk of code. Remember, use relative file pathways, and never include any personal computer file pathways.
#
# This is also a good place to load any data from other built-in packages or pulled with an API.

# %%
# load in data

# %% [markdown]
# ## Get data ready for plotting
#
# This next section is for doing any pre-processing steps, data joins, etc, to get your data ready for plotting.
#
# If your processing is expensive or involved, feel free to put in into a separate
# notebook and read in the processed output here.

# %%
# process data

# %% [markdown]
# ## Generate chart for mobile

# %% [markdown]
# ### Set up main plot
#
# This chunk is where the main `matplotlib` set-up occurs.

# %% [markdown]
# #### Figure set-up

# %%
# set up figure parameters
mobile_height = 16
mobile_width = 9
plot_background_color = 'white'

# %%
# set up figure
fig = plt.figure(figsize=(mobile_width, mobile_height), constrained_layout=False) # constrained layout must be False to adjust subplot sizes within grid

# %%
# set up a grid for the subplots within the figure
# Add a gridspec with 3 rows (title, figure, citation) and set the ratio between the rows
# Here we're only adding 1 column, but if your plot contains subplots
# you could add more columns (or more rows)
# if you add >1 column you need to set the width ratios: e.g, width_ratios = (1,0.5) for 2 columns
# arguments 'left','right','top', and 'bottom' set the extent of the subplots as a fraction 
# of figure width or height. Left cannot be larger than right, and bottom cannot be larger than top.
# wspace and hspace set width and height reserved as spacing between plots, respectively 
# See docs here: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.gridspec.GridSpec.html#matplotlib.gridspec.GridSpec
# See tutorial here: https://matplotlib.org/3.1.1/tutorials/intermediate/gridspec.html
# You likely will need to tweak 'left' and 'right' to correctly center your plot(s)
# And wspace and hspace to allow room for your axes

# here we're setting the main plot to be 13 tall
main_plot_height = 13
# we'll divide the remaining height between placeholders for the title and for the data source + USGS logo
gs = fig.add_gridspec(3, 1, 
                      height_ratios=((mobile_height-main_plot_height)/2, 
                                     main_plot_height, 
                                     (mobile_height-main_plot_height)/2),
                      left=0.05, right=0.95, bottom=0, top=1,
                      wspace=0.18, hspace=0)

# %%
# add placeholders for a figure title (row 0, col 0) and a data source citation (row 2, col 0)
ax_title = fig.add_subplot(gs[0,0])
ax_title.axis('off')
ax_citation = fig.add_subplot(gs[2,0])
ax_citation.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# #### Figure generation

# %%
# Build the main plots (in row 1)
ax_plot = fig.add_subplot(gs[1, 0])

# %%
# Check fig - REMBEMBER: only row 1 will have plots, since we've put in blank placeholders for the title and citation
fig

# %% [markdown]
# ## Produce final plot
# Here, add the data source and USGS logo to create the final viz.

# %% [markdown]
# #### Load USGS logo

# %%
logo_color = 'black' # 'black' or 'white'
logo = image.imread(f'../usgs_logo_{logo_color}.png')

# %% [markdown]
# #### Compose final plot

# %%
horizontal_margin = 0.05
vertical_margin = 0.03
title_font_size = 55
explainer_font_size = 16

# %% [markdown]
# ##### Add plot title

# %%
# add additional axis to hold title
# position = (0,0), width = 100% of figure width (1), height = 100% of figure height (1)
title_ax = fig.add_axes([0, 0, 1, 1], anchor = 'SW', facecolor='none')

# %%
# check axis params
# adjust width and height params for text axis until axis fully covers entire plot w/o extending further
fig

# %%
# Add title, specifying color, style, and alignment
# see https://matplotlib.org/stable/gallery/text_labels_and_annotations/text_alignment.html
# for alignment tips
title_ax.text(x = horizontal_margin, y = 0.97, s = 'Chart title', horizontalalignment='left', verticalalignment = 'top', color = 'black', fontsize = title_font_size, fontstyle = 'normal')
# remove axis lines
title_ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# check placement
fig

# %% [markdown]
# ##### Add data source

# %%
# add additional axis to hold text 
# position = (0,0), width = 100% of figure width (1), height = 100% of figure height (1)
text_ax = fig.add_axes([0, 0, 1, 1], anchor = 'SW', facecolor='none')
# Out:
# C:\Users\hcorson-dosch\Anaconda3\envs\geo\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# check axis params
# adjust width and height params for text axis until axis fully covers entire plot w/o extending further
fig

# %%
# Add text, specifying color, style, and alignment
# see https://matplotlib.org/stable/gallery/text_labels_and_annotations/text_alignment.html
# for alignment tips
text_ax.text(x = 1-horizontal_margin, y = vertical_margin, s = 'Data Source\nin multiple\nlines', horizontalalignment = 'right', verticalalignment = 'bottom', color = 'grey', fontsize = explainer_font_size, fontstyle = 'italic')
# remove axis lines
text_ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# check placement
fig

# %% [markdown]
# ##### Add USGS logo

# %%
# set width and height fractions for logo
logo_width_fraction = 0.2
logo_height_fraction = 0.05

# %%
# add additional axis to hold logo
logo_ax = fig.add_axes([horizontal_margin,vertical_margin, logo_width_fraction, logo_height_fraction], anchor = 'SW', facecolor='none')

# %%
# check axis params
fig

# %%
# now add logo to axis, and remove axis lines
logo_ax.imshow(logo)
logo_ax.axis('off')
# Out:
# (-0.5, 2753.5, 1017.5, -0.5)

# %%
fig

# %% [markdown]
# #### Save figure

# %%
# Save the final image
fig.savefig('out/py_yourproject_yourname_mobile.png', dpi=300, facecolor = plot_background_color)

# %% [markdown]
# ## Generate chart for Instagram

# %% [markdown]
# ### Set up main plot
#
# This chunk is where the main `matplotlib` set-up occurs.

# %% [markdown]
# #### Figure set-up

# %%
# set up figure parameters
square_dim = 9
plot_background_color = 'white'

# %%
# set up figure
fig = plt.figure(figsize=(square_dim, square_dim), constrained_layout=False) # constrained layout must be False to adjust subplot sizes within grid

# %%
# set up a grid for the subplots within the figure
# Add a gridspec with 3 rows (title, figure, citation) and set the ratio between the rows
# Here we're only adding 1 column, but if your plot contains subplots
# you could add more columns (or more rows)
# if you add >1 column you need to set the width ratios: e.g, width_ratios = (1,0.5) for 2 columns
# arguments 'left','right','top', and 'bottom' set the extent of the subplots as a fraction 
# of figure width or height. Left cannot be larger than right, and bottom cannot be larger than top.
# wspace and hspace set width and height reserved as spacing between plots, respectively 
# See docs here: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.gridspec.GridSpec.html#matplotlib.gridspec.GridSpec
# See tutorial here: https://matplotlib.org/3.1.1/tutorials/intermediate/gridspec.html
# You likely will need to tweak 'left' and 'right' to correctly center your plot(s)
# And wspace and hspace to allow room for your axes

# here we're setting the main plot to be 6 tall
main_plot_height = 6
# we'll divide the remaining height between placeholders for the title and for the data source + USGS logo
gs = fig.add_gridspec(3, 1, 
                      height_ratios=((square_dim-main_plot_height)/2, 
                                     main_plot_height, 
                                     (square_dim-main_plot_height)/2),
                      left=0.05, right=0.95, bottom=0, top=1,
                      wspace=0.18, hspace=0)

# %%
# add placeholders for a figure title (row 0, col 0) and a data source citation (row 2, col 0)
ax_title = fig.add_subplot(gs[0,0])
ax_title.axis('off')
ax_citation = fig.add_subplot(gs[2,0])
ax_citation.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# #### Figure generation

# %%
# Build the main plots (in row 1)
ax_plot = fig.add_subplot(gs[1, 0])

# %%
# Check fig - REMBEMBER: only row 1 will have plots, since we've put in blank placeholders for the title and citation
fig

# %% [markdown]
# ## Produce final plot
# Here, add the data source and USGS logo to create the final viz.

# %% [markdown]
# #### Load USGS logo

# %%
logo_color = 'black' # 'black' or 'white'
logo = image.imread(f'../usgs_logo_{logo_color}.png')

# %% [markdown]
# #### Compose final plot

# %%
horizontal_margin = 0.05
vertical_margin = 0.03
title_font_size = 40
explainer_font_size = 16

# %% [markdown]
# ##### Add plot title

# %%
# add additional axis to hold title
# position = (0,0), width = 100% of figure width (1), height = 100% of figure height (1)
title_ax = fig.add_axes([0, 0, 1, 1], anchor = 'SW', facecolor='none')

# %%
# check axis params
# adjust width and height params for text axis until axis fully covers entire plot w/o extending further
fig

# %%
# Add title, specifying color, style, and alignment
# see https://matplotlib.org/stable/gallery/text_labels_and_annotations/text_alignment.html
# for alignment tips
title_ax.text(x = horizontal_margin, y = 0.95, s = 'Chart title', horizontalalignment='left', verticalalignment = 'top', color = 'black', fontsize = title_font_size, fontstyle = 'normal')
# remove axis lines
title_ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# check placement
fig

# %% [markdown]
# ##### Add data source

# %%
# add additional axis to hold text 
# position = (0,0), width = 100% of figure width (1), height = 100% of figure height (1)
text_ax = fig.add_axes([0, 0, 1, 1], anchor = 'SW', facecolor='none')
# Out:
# C:\Users\hcorson-dosch\Anaconda3\envs\geo\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# check axis params
# adjust width and height params for text axis until axis fully covers entire plot w/o extending further
fig

# %%
# Add text, specifying color, style, and alignment
# see https://matplotlib.org/stable/gallery/text_labels_and_annotations/text_alignment.html
# for alignment tips
text_ax.text(x = 1-horizontal_margin, y = vertical_margin, s = 'Data Source\nin multiple\nlines', horizontalalignment = 'right', verticalalignment = 'bottom', color = 'grey', fontsize = explainer_font_size, fontstyle = 'italic')
# remove axis lines
text_ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# check placement
fig

# %% [markdown]
# ##### Add USGS logo

# %%
# set width and height fractions for logo
logo_width_fraction = 0.2
logo_height_fraction = 0.09

# %%
# add additional axis to hold logo
logo_ax = fig.add_axes([horizontal_margin,vertical_margin, logo_width_fraction, logo_height_fraction], anchor = 'SW', facecolor='none')

# %%
# check axis params
fig

# %%
# now add logo to axis, and remove axis lines
logo_ax.imshow(logo)
logo_ax.axis('off')
# Out:
# (-0.5, 2753.5, 1017.5, -0.5)

# %%
fig

# %% [markdown]
# #### Save figure

# %%
# Save the final image
fig.savefig('out/py_yourproject_yourname_square.png', dpi=300, facecolor = plot_background_color)

# %% [markdown]
# ## Supporting information
#
# ### Caption with key message communicated by this viz
#
# 1. Key takeaways here
#
# ### Data source(s)
#
# Data sources here.
#
# ### Alt text
#
# Alt text for visualization here
#
# ### Authors
#
# List authors here
